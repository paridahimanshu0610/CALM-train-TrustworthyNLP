# %%
import json

data = []
with open('/Users/himanshu/Documents/Projects/CALM-train-TrustworthyNLP/data/CRA_resample_0.045M.json', 'r', encoding='utf-8') as f:
    for line in f:
        data.append(json.loads(line))

data[0]
# Out:
# {'instruction': "Detect the credit card fraud with the following financial profile. Respond with only 'good' or 'bad', and do not provide any additional information. For instance, 'The client is a female, the state number is 25, the number of cards is 1, the credit balance is 7000, the number of transactions is 16, the number of international transactions is 0, the credit limit is 6.' should be classified as 'good'. \nText: 'The client is a female, the state number is 32, the number of cards is 1, the credit balance is 0, the number of transactions is 37, the number of international transactions is 7, the credit limit is 2.' \nAnswer:",
#  'input': '',
#  'output': 'good'}

# %%
cnt = 0

for temp in data:
    if len(temp['input']) == 0:
        cnt += 1
print(cnt)

data[0].keys()
# Out:
# 47863
# dict_keys(['instruction', 'input', 'output'])
